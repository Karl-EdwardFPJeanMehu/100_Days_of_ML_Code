# %% [markdown]
# <a href="https://colab.research.google.com/github/Karl-EdwardFPJeanMehu/100_Days_of_ML_Code/blob/master/Copy_of_Hospital_Clinics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install package to load .env file
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
# Import the .env file
from google.colab import userdata
secret_key = userdata.get('SERP_API_KEY')
address = userdata.get('address')
print(secret_key)
print(address)
# Out:
# 5f59db50304d81f49f50e3971a026c3720892de6066168e9048c9544f66514c5
# 418 w 17 st, New York, NY 10011

# %%
# Execute the SERP search
import requests, pprint

def find_healthcare_institutions_near_address(query, address, api_key):
    params = {
        "q": query + address,  # The search query for clinics near the address
        "location": address,  # The specific address
        "engine": "google_maps",  # Use the Google Maps engine
        "type": "search",  # We're looking for place search results,
        "location_requested": "New York, United States",
        "location_used": "New York,United States",
        "hl": "en",  # Language
        "gl": 'us',
        "api_key": api_key  # Your SerpAPI key
    }

    response = requests.get("https://serpapi.com/search", params=params)
    data = response.json()

    # Parse the results
    clinics = data.get("local_results", [])
    return clinics

clinics = find_healthcare_institutions_near_address("hospitals or clinics near ", address, secret_key)

# print(clinics)

# Display results
# for clinic in clinics:
#     print(f"Name: {clinic['title']}")
#     print(f"Address: {clinic['address']}")
#     print(f"Rating: {clinic.get('rating', 'No rating')}")
    # print(f"Link: {clinic['link']}")
    # print("---------------")

# Print the first object in the clinics array with indenting
# pprint.pprint(clinics[0], indent=3)

# address, hours, open_state, operating_housrs, phone, rating, title
# type, website
import pandas as pd
df = pd.DataFrame(clinics, columns=['title', 'phone', 'address', 'hours', 'open_state', 'operating_hours',
                                    'rating', 'website', 'type'])
# Remove rows without a website
filtered = df[df['website'].notnull()]
filtered.sort_values(by='rating', ascending=False)
# Out:
#                                                 title           phone  \
# 17                           Manhattan Specialty Care  (212) 843-9496
# 13  NewYork-Presbyterian Ambulatory Care Network -...  (212) 746-7200
# 1                            Manhattan Specialty Care  (212) 378-9982
# 14    MiDoctor - Walk-in Urgent Care - Hell's Kitchen  (212) 757-3859
# 19                  New York Preventive Health Center  (718) 997-7100
# 8                  CityMD West 14th Urgent Care - NYC  (212) 390-0558
# 11                      NYU Langone Hospital Brooklyn  (718) 630-7000
# 15              Urgent Care at NYU Langone at Trinity  (646) 461-2544
# 4                                  NYU Langone Health  (646) 929-7800
# 6       NewYork-Presbyterian Lower Manhattan Hospital  (212) 312-5000
# 7                             Mount Sinai Beth Israel  (212) 420-2000
# 18  Urgent Care at NYU Langone Ambulatory Care Wes...  (646) 754-2599
# 5                      Lenox Health Greenwich Village  (646) 665-6000
# 12                     Amsterdam Family Health Center  (212) 865-4104
# 3                 NYC Health + Hospitals/Metropolitan  (212) 423-6262
# 2   The Blavatnik Family – Chelsea Medical Center ...  (212) 604-6000
# 16              NYU Langone Ambulatory Care West Side  (646) 754-2100
# 9                                    Mount Sinai West  (212) 523-4000
# 10            Washington Heights Family Health Center  (866) 463-2778
# 0          The Institute for Family Health at 17th St  (212) 206-5200
#
#                                              address               hours  \
# 17           80 Maiden Ln 1204 G, New York, NY 10038  Open ⋅ Closes 7 PM
# 13        53 W 23rd St 6th floor, New York, NY 10011  Open ⋅ Closes 5 PM
# 1           55 W 17th St STE 100, New York, NY 10011  Open ⋅ Closes 7 PM
# 14                   715 9th Ave, New York, NY 10019  Open ⋅ Closes 8 PM
# 19  68-60 Austin St Store 10, Forest Hills, NY 11375  Open ⋅ Closes 5 PM
# 8                   14 W 14th St, New York, NY 10011  Open ⋅ Closes 9 PM
# 11                   150 55th St, Brooklyn, NY 11220       Open 24 hours
# 15                  111 Broadway, New York, NY 10006                 NaN
# 4                   550 1st Ave., New York, NY 10016       Open 24 hours
# 6                 170 William St, New York, NY 10038       Open 24 hours
# 7                   281 1st Ave., New York, NY 10003       Open 24 hours
# 18       355 W 52nd St 5th floor, New York, NY 10019                 NaN
# 5                     30 7th Ave, New York, NY 10011       Open 24 hours
# 12             690 Amsterdam Ave, New York, NY 10025  Open ⋅ Closes 8 PM
# 3                  1901 1st Ave., New York, NY 10029       Open 24 hours
# 2                  325 W 15th St, New York, NY 10011  Open ⋅ Closes 5 PM
# 16                 355 W 52nd St, New York, NY 10019                 NaN
# 9                  1000 10th Ave, New York, NY 10019       Open 24 hours
# 10                575 W 181st St, New York, NY 10033  Open ⋅ Closes 5 PM
# 0                  230 W 17th St, New York, NY 10011  Open ⋅ Closes 6 PM
#
#             open_state                                    operating_hours  \
# 17  Open ⋅ Closes 7 PM  {'monday': '8 AM–7 PM', 'tuesday': '8 AM–7 PM'...
# 13  Open ⋅ Closes 5 PM  {'monday': '9 AM–5 PM', 'tuesday': '9 AM–5 PM'...
# 1   Open ⋅ Closes 7 PM  {'monday': '7:30 AM–7 PM', 'tuesday': '7:30 AM...
# 14  Open ⋅ Closes 8 PM  {'monday': '8 AM–8 PM', 'tuesday': '8 AM–8 PM'...
# 19  Open ⋅ Closes 5 PM  {'monday': '9 AM–5 PM', 'tuesday': '9 AM–5 PM'...
# 8   Open ⋅ Closes 9 PM  {'monday': '9 AM–9 PM', 'tuesday': '9 AM–9 PM'...
# 11       Open 24 hours  {'monday': 'Open 24 hours', 'tuesday': 'Open 2...
# 15            Open now                                                NaN
# 4        Open 24 hours  {'monday': 'Open 24 hours', 'tuesday': 'Open 2...
# 6        Open 24 hours  {'monday': 'Open 24 hours', 'tuesday': 'Open 2...
# 7        Open 24 hours  {'monday': 'Open 24 hours', 'tuesday': 'Open 2...
# 18            Open now                                                NaN
# 5        Open 24 hours  {'monday': 'Open 24 hours', 'tuesday': 'Open 2...
# 12  Open ⋅ Closes 8 PM  {'monday': '8:30 AM–8 PM', 'tuesday': '8:30 AM...
# 3        Open 24 hours  {'monday': 'Open 24 hours', 'tuesday': 'Open 2...
# 2   Open ⋅ Closes 5 PM  {'monday': '8:30 AM–5 PM', 'tuesday': '8:30 AM...
# 16            Open now                                                NaN
# 9        Open 24 hours  {'monday': 'Open 24 hours', 'tuesday': 'Open 2...
# 10  Open ⋅ Closes 5 PM  {'monday': '8:30 AM–5 PM', 'tuesday': '8:30 AM...
# 0   Open ⋅ Closes 6 PM  {'monday': '8 AM–6 PM', 'tuesday': '8 AM–8 PM'...
#
#     rating                                            website  \
# 17     5.0                                 http://mscnyc.com/
# 13     5.0  https://www.nyp.org/acn/primary-care/center-fo...
# 1      4.7  http://www.manhattanspecialtycare.com/?utm_sou...
# 14     4.6                           https://midochealth.com/
# 19     4.6                             https://nypclinic.com/
# 8      4.2  https://www.citymd.com/urgent-care-locations/n...
# 11     3.9  https://nyulangone.org/locations/nyu-langone-h...
# 15     3.8  https://nyulangone.org/locations/nyu-langone-a...
# 4      3.7  https://nyulangone.org/?cid=syn_yext&y_entity_...
# 6      3.6  https://www.nyp.org/lowermanhattan?utm_source=...
# 7      3.3  https://www.mountsinai.org/locations/beth-isra...
# 18     3.3  https://nyulangone.org/locations/nyu-langone-a...
# 5      3.2  https://www.northwell.edu/lenox-health-greenwi...
# 12     3.2                          http://www.institute.org/
# 3      3.2  http://www.nychealthandhospitals.org/metropolitan
# 2      3.1  https://www.mountsinai.org/locations/chelsea?u...
# 16     2.9  https://nyulangone.org/locations/nyu-langone-a...
# 9      2.9  https://www.mountsinai.org/locations/west?utm_...
# 10     2.8  https://www.nyp.org/acn/primary-care/washingto...
# 0      2.3                          http://www.institute.org/
#
#                   type
# 17              Doctor
# 13            Hospital
# 1       Medical clinic
# 14      Medical clinic
# 19      Medical Center
# 8   Urgent care center
# 11            Hospital
# 15  Urgent care center
# 4             Hospital
# 6             Hospital
# 7     General hospital
# 18  Urgent care center
# 5       Emergency room
# 12      Medical clinic
# 3       Medical Center
# 2             Hospital
# 16      Medical clinic
# 9             Hospital
# 10      Medical clinic
# 0       Medical clinic

# %%
shape = filtered.shape
print(f'There are {shape[0]} clinics in NY with {shape[1]} fields')
# Out:
# There are 20 clinics in NY with 9 fields

# %%
# Convert the Pandas df into Google Sheets
csv_data = filtered.to_csv();

# Install pygsheets
# !pip install pygsheets
import pygsheets, os

path = "/content/galvanic-augury-431216-k5-1a3cfbfcec7a.json"

# os.access(path, os.R_OK)

# Ensure file exists
if not os.path.exists(path):
    print("File does not exist.")
    exit()  # Exit if the file does not exist

# Authorize with Google Sheets API
# print(path)
gc = pygsheets.authorize(service_file=path)

spreadsheet = gc.open('Clinics')  # Replace with your sheet name

worksheet = spreadsheet.sheet1  # You can also use .get_worksheet(index) to specify the sheet

# Clear existing content (optional)
worksheet.clear()

# Update the sheet with DataFrame values
worksheet.set_dataframe(filtered, (1, 1))  # Starting from the first row and first column

print("DataFrame written to Google Sheets successfully!")
# Out:
# Requirement already satisfied: pygsheets in /usr/local/lib/python3.10/dist-packages (2.0.6)
# Requirement already satisfied: google-api-python-client>=2.50.0 in /usr/local/lib/python3.10/dist-packages (from pygsheets) (2.137.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pygsheets) (1.2.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.50.0->pygsheets) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.50.0->pygsheets) (2.27.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.50.0->pygsheets) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.50.0->pygsheets) (2.19.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.50.0->pygsheets) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.7.1->pygsheets) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (3.20.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (1.24.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=2.50.0->pygsheets) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=2.50.0->pygsheets) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=2.50.0->pygsheets) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=2.50.0->pygsheets) (3.1.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.1->pygsheets) (3.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=2.50.0->pygsheets) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=2.50.0->pygsheets) (2024.8.30)
# File does not exist.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-3f4895112a10> in <cell line: 19>()
#      17 # Authorize with Google Sheets API
#      18 # print(path)
# ---> 19 gc = pygsheets.authorize(service_file=path)
#      20
#      21 spreadsheet = gc.open('Clinics')  # Replace with your sheet name
#
# /usr/local/lib/python3.10/dist-packages/pygsheets/authorization.py in authorize(client_secret, service_account_file, service_account_env_var, service_account_json, credentials_directory, scopes, custom_credentials, local, **kwargs)
#     135             service_account_info, scopes=scopes)
#     136     elif service_account_file is not None:
# --> 137         credentials = service_account.Credentials.from_service_account_file(service_account_file, scopes=scopes)
#     138     else:
#     139         credentials = _get_user_authentication_credentials(client_secret, scopes, credentials_directory, local)
#
# /usr/local/lib/python3.10/dist-packages/google/oauth2/service_account.py in from_service_account_file(cls, filename, **kwargs)
#     255                 credentials.
#     256         """
# --> 257         info, signer = _service_account_info.from_filename(
#     258             filename, require=["client_email", "token_uri"]
#     259         )
#
# /usr/local/lib/python3.10/dist-packages/google/auth/_service_account_info.py in from_filename(filename, require, use_rsa_signer)
#      76             info and a signer instance.
#      77     """
# ---> 78     with io.open(filename, "r", encoding="utf-8") as json_file:
#      79         data = json.load(json_file)
#      80         return data, from_dict(data, require=require, use_rsa_signer=use_rsa_signer)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/galvanic-augury-431216-k5-1a3cfbfcec7a.json'

# %%
# !pip install playsound
# !pip install pygobject

# %%
import time, sys, os
# from playsound import playsound

message = "Here is something to ponder \r\
about the way I may want to try creating\r \ the typewriter effect in Python. \r \ Here is something to ponder about the way I may want to try creating the typewriter effect in Python."

def type_effect(msg, speed = 0.05):
  for char in msg:
    # Write the individual character and wait before continuing.
    sys.stdout.write(char)
    sys.stdout.flush()

    # Check and pause if the character is a new line
    if (char != "\n"):
      time.sleep(speed)
    else:
      time.sleep(speed*2)

# type_effect(message, 0.1)
# playsound("sound.mp3", 0)

# %%
#
